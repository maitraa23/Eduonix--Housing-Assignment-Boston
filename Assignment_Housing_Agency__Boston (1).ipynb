# %% [markdown]
# ## Assignment - Statistics for Data Science with Python

# %% [markdown]
# ### Load Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import statsmodels.api as sm

# %%
boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
boston_df = pd.read_csv(boston_url)

# %%
boston_df.describe()
# Out:
#        Unnamed: 0        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
boston_df.head(10)
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0
# 5           5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0
# 6           6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0
# 7           7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0
# 8           8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0
# 9           9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0
#
#      TAX  PTRATIO  LSTAT  MEDV
# 0  296.0     15.3   4.98  24.0
# 1  242.0     17.8   9.14  21.6
# 2  242.0     17.8   4.03  34.7
# ...

# %% [markdown]
# ### Become familiar with the dataset
# The following describes the dataset variables:
#
# ·      CRIM - per capita crime rate by town
#
# ·      ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
#
# ·      INDUS - proportion of non-retail business acres per town.
#
# ·      CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#
# ·      NOX - nitric oxides concentration (parts per 10 million)
#
# ·      RM - average number of rooms per dwelling
#
# ·      AGE - proportion of owner-occupied units built prior to 1940
#
# ·      DIS - weighted distances to five Boston employment centres
#
# ·      RAD - index of accessibility to radial highways
#
# ·      TAX - full-value property-tax rate per $10,000
#
# ·      PTRATIO - pupil-teacher ratio by town
#
# ·      LSTAT - % lower status of the population
#
# ·      MEDV - Median value of owner-occupied homes in $1000's

# %% [markdown]
# ### Generate Descriptive Statistics and Visualizations
# #### Question 1: For the 'Median value of owner-occupied homes' provide a boxplot
#
# Evalution : This question carries 10 marks

# %%
# Solution goes here:
sns.boxplot(boston_df['MEDV'])
plt.title('Boxplot showing Median Value of Owner Occupied Homes')
plt.show()

# %%
## Data has a lot of outliers which means the data provided for Median Value of Owner Occupied Homes is not equally distributed and has extreme values

# %% [markdown]
#  Question 2: Provide a histogram for the Charles River variable
#
# Evalution : This question carries 20 marks

# %%
# Solution goes here:
sns.histplot(boston_df['CHAS'],bins=10,color='green')
plt.title('Histogram for Charles River Variable')
plt.xlabel('Charles River Dummy Variable')
plt.ylabel('Total Count')
plt.show()

# %%
## Inference: The histogram shows that a majority of the tracts do not bound the Charles River.
## This suggests that proximity to the river may be a less common feature in this dataset.

# %% [markdown]
# #### Question 3: Provide a boxplot for the MEDV variable vs the AGE variable - Discretize the age variable into three groups of 35 years and younger, between 35 and 50 years and older
#
# Evalution : This question carries 20 marks

# %%
# Solution goes here:
boston_df.loc[(boston_df['AGE'] <= 35), 'age_group'] = '35 years and younger'
boston_df.loc[(boston_df['AGE'] > 35)&(boston_df['AGE'] < 50), 'age_group'] = 'between 35 and 50 years'
boston_df.loc[(boston_df['AGE'] >= 50), 'age_group'] = '50 years and older'

palette = {'35 years and younger': 'skyblue','between 35 and 50 years': 'lightgreen','50 years and older': 'yellow'}
sns.boxplot(x='age_group', y='MEDV', data=boston_df,palette=palette)
plt.xlabel('Age Group')
plt.ylabel('Median Value of Owner-Occupied Homes (MEDV)')
plt.title('Boxplot of MEDV vs Age Group')
plt.show()
# Out:
# <ipython-input-55-0f6f3813c938>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='age_group', y='MEDV', data=boston_df,palette=palette)

# %%
# Inference:
# - The median value of houses seems to decrease with the age of the house
# - The oldest houses (50 years and older) have the lowest median value while the newest houses (35 years and younger) have the highest median value.
# - There is a higher spread in the median value of houses for the newest houses (35 years and younger) compared to the other two age groups.

# %% [markdown]
# #### Question 4: Provide a scatter plot to show the relationship between Nitric oxide concentrations and the proportion of non-retail business acres per town. What can you say about the relationship?
#
# Evalution : This question carries 20 marks

# %%
# Solution goes here:
sns.scatterplot(x='NOX', y='INDUS', data=boston_df, color='red')
plt.xlabel('Nitric Oxide Concentration')
plt.ylabel('Proportion of Non-Retail Business Acres per Town')
plt.title('Relationship between NOX and INDUS')
plt.show()

# There appears to be a positive linear relationship between nitric oxide concentrations and the proportion of non-retail business acres per town.
# This suggests that areas with a higher proportion of non-retail business tend to have higher levels of nitric oxide pollution.

# %% [markdown]
# #### Question 5: Create a histogram for the pupil to teacher ratio variable.
#
# Evalution : This question carries 20 marks

# %%
# Solution goes here:
sns.histplot(boston_df['PTRATIO'],bins=10,kde=True,color='skyblue')
plt.title('Histogram showing Pupil to Teacher ratio')
plt.xlabel('Pupil to Teacher ratio')
plt.ylabel('Frequency')
plt.show()

# %%
# Inference:
# The distribution of the pupil-teacher ratio is slightly right-skewed, with a peak around 20 students per teacher.
# This suggests that most towns in the dataset have a pupil-teacher ratio around 20.
# There are a few towns with higher pupil-teacher ratios, indicating potential disparities in educational resources across different areas.

# %% [markdown]
# #### Question 6: Can we conclude that there is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town? (Pearson Correlation)
#
# Evalution : This question carries 10 marks

# %%
# Solution goes here:
correlation_coefficient, p_value = scipy.stats.pearsonr(boston_df['NOX'], boston_df['INDUS'])

print("Pearson correlation coefficient:", correlation_coefficient)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05  # Set significance level
if p_value < alpha:
    print("We reject the null hypothesis of no correlation.")
    print("There is evidence of a statistically significant relationship between Nitric oxide concentrations and proportion of non-retail business acres per town.")
else:
    print("We fail to reject the null hypothesis of no correlation.")
    print("There is no evidence of a statistically significant relationship between Nitric oxide concentrations and proportion of non-retail business acres per town.")
# Out:
# Pearson correlation coefficient: 0.7636514469209151
# p-value: 7.913361061239527e-98
# We reject the null hypothesis of no correlation.
# There is evidence of a statistically significant relationship between Nitric oxide concentrations and proportion of non-retail business acres per town.
